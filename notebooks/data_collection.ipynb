# %%
import sys
from pathlib import Path
import pandas as pd
import os

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

from src.spotify_client import init_spotify
from src.collect import (
    get_liked_songs,
    parse_tracks,
    get_artist_metadata,
)

# %% [markdown]
# ### 1. Authentication

# %%
sp = init_spotify()
print("Authenticated as:", sp.current_user()["display_name"])
# Out:
# Authenticated as: Joe Ledford

# %% [markdown]
# ### 2. Liked Songs & Track Metadata Extraction

# %%
liked_songs = get_liked_songs(sp)
print(f"Total liked songs retrieved: {len(liked_songs)}")

track_metadata = parse_tracks(liked_songs)
print(track_metadata.shape)
print(track_metadata.head())

track_metadata.to_csv("../data/raw/track_metadata.csv", index=False)
# Out:
# Total liked songs retrieved: 2128
# (2128, 7)
#                  track_id              track_name        artist  \
# 0  7AHX0F99w4x23uSZihklZ6                  My God        Tapir!
# 1  1KbpVvPiLAt1Wsh5gr2YKM             Take a Trip       TV Girl
# 2  56s4IHGnJVGZYcdOVmC3eb  I Love Life, Thank You    Mac Miller
# 3  5XufqHphZkJhIkc5wlEST7          Soft Rock Band  Good Morning
# 4  6HqdxpWOasNjyjLFVXCB6x            Superbloomer    Arcy Drive
#
#                 artist_id                                              album  \
# 0  7dYpljfleToKnSmBFqjqkd  The Pilgrim, Their God and The King of My Decr...
# 1  0Y6dVaC9DZtPNH4591M42W                                       Fauxllennium
# 2  4LLpKhyESsyAXpc4laK94U                             I Love Life, Thank You
# 3  2kMzxA8edU05hvMFU493zJ                                     Soft Rock Band
# 4  7o1TBmx7Ube5h2Czlam84O                                       Superbloomer
#
#   release_date              added_at
# 0   2024-01-26  2026-03-30T19:33:55Z
# 1   2024-12-02  2026-03-29T16:54:47Z
# 2   2022-07-22  2026-03-29T16:31:35Z
# 3   2024-11-18  2026-03-29T16:15:50Z
# 4   2023-10-30  2026-03-29T16:09:07Z
